# %%
import tensorflow as tf

# %%
def encoder_block(inputs, num_filters): 

	# Convolution with 3x3 filter followed by ReLU activation 
	x = tf.keras.layers.Conv2D(num_filters, 
							3, 
							padding = 'valid')(inputs) 
	x = tf.keras.layers.Activation('relu')(x) 
	
	# Convolution with 3x3 filter followed by ReLU activation 
	x = tf.keras.layers.Conv2D(num_filters, 
							3, 
							padding = 'valid')(x) 
	x = tf.keras.layers.Activation('relu')(x) 

	# Max Pooling with 2x2 filter 
	x = tf.keras.layers.MaxPool2D(pool_size = (2, 2), 
								strides = 2)(x) 
	
	return x

# %%
def decoder_block(inputs, skip_features, num_filters): 

	# Upsampling with 2x2 filter 
	x = tf.keras.layers.Conv2DTranspose(num_filters, 
										(2, 2), 
										strides = 2, 
										padding = 'valid')(inputs) 
	
	# Copy and crop the skip features 
	# to match the shape of the upsampled input 
	skip_features = tf.image.resize(skip_features, 
									size = (x.shape[1], 
											x.shape[2])) 
	x = tf.keras.layers.Concatenate()([x, skip_features]) 
	
	# Convolution with 3x3 filter followed by ReLU activation 
	x = tf.keras.layers.Conv2D(num_filters, 
							3, 
							padding = 'valid')(x) 
	x = tf.keras.layers.Activation('relu')(x) 

	# Convolution with 3x3 filter followed by ReLU activation 
	x = tf.keras.layers.Conv2D(num_filters, 3, padding = 'valid')(x) 
	x = tf.keras.layers.Activation('relu')(x) 
	
	return x

# %%
def unet_model(input_shape = (256, 256, 3), num_classes = 1): 
	inputs = tf.keras.layers.Input(input_shape) 
	
	# Contracting Path 
	s1 = encoder_block(inputs, 64) 
	s2 = encoder_block(s1, 128) 
	s3 = encoder_block(s2, 256) 
	s4 = encoder_block(s3, 512) 
	
	# Bottleneck 
	b1 = tf.keras.layers.Conv2D(1024, 3, padding = 'valid')(s4) 
	b1 = tf.keras.layers.Activation('relu')(b1) 
	b1 = tf.keras.layers.Conv2D(1024, 3, padding = 'valid')(b1) 
	b1 = tf.keras.layers.Activation('relu')(b1) 
	
	# Expansive Path 
	s5 = decoder_block(b1, s4, 512) 
	s6 = decoder_block(s5, s3, 256) 
	s7 = decoder_block(s6, s2, 128) 
	s8 = decoder_block(s7, s1, 64) 
	
	# Output 
	outputs = tf.keras.layers.Conv2D(num_classes, 
									1, 
									padding = 'valid', 
									activation = 'sigmoid')(s8) 
	
	model = tf.keras.models.Model(inputs = inputs, 
								outputs = outputs, 
								name = 'U-Net') 
	return model 

model = unet_model()
model.summary()
# Out:
# Model: "U-Net"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 254, 254, 64  1792        ['input_1[0][0]']
#                                 )
#
#  activation (Activation)        (None, 254, 254, 64  0           ['conv2d[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 252, 252, 64  36928       ['activation[0][0]']
#                                 )
#
#  activation_1 (Activation)      (None, 252, 252, 64  0           ['conv2d_1[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 126, 126, 64  0           ['activation_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 124, 124, 12  73856       ['max_pooling2d[0][0]']
#                                 8)
#
#  activation_2 (Activation)      (None, 124, 124, 12  0           ['conv2d_2[0][0]']
#                                 8)
#
#  conv2d_3 (Conv2D)              (None, 122, 122, 12  147584      ['activation_2[0][0]']
#                                 8)
#
#  activation_3 (Activation)      (None, 122, 122, 12  0           ['conv2d_3[0][0]']
#                                 8)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 61, 61, 128)  0          ['activation_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 59, 59, 256)  295168      ['max_pooling2d_1[0][0]']
#
#  activation_4 (Activation)      (None, 59, 59, 256)  0           ['conv2d_4[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 57, 57, 256)  590080      ['activation_4[0][0]']
#
#  activation_5 (Activation)      (None, 57, 57, 256)  0           ['conv2d_5[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 28, 28, 256)  0          ['activation_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 26, 26, 512)  1180160     ['max_pooling2d_2[0][0]']
#
#  activation_6 (Activation)      (None, 26, 26, 512)  0           ['conv2d_6[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 24, 24, 512)  2359808     ['activation_6[0][0]']
#
#  activation_7 (Activation)      (None, 24, 24, 512)  0           ['conv2d_7[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 12, 12, 512)  0          ['activation_7[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 10, 10, 1024  4719616     ['max_pooling2d_3[0][0]']
#                                 )
#
#  activation_8 (Activation)      (None, 10, 10, 1024  0           ['conv2d_8[0][0]']
#                                 )
#
#  conv2d_9 (Conv2D)              (None, 8, 8, 1024)   9438208     ['activation_8[0][0]']
#
#  activation_9 (Activation)      (None, 8, 8, 1024)   0           ['conv2d_9[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 16, 16, 512)  2097664    ['activation_9[0][0]']
#  ose)
#
#  tf.image.resize (TFOpLambda)   (None, 16, 16, 512)  0           ['max_pooling2d_3[0][0]']
#
#  concatenate (Concatenate)      (None, 16, 16, 1024  0           ['conv2d_transpose[0][0]',
#                                 )                                 'tf.image.resize[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 14, 14, 512)  4719104     ['concatenate[0][0]']
#
#  activation_10 (Activation)     (None, 14, 14, 512)  0           ['conv2d_10[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 12, 12, 512)  2359808     ['activation_10[0][0]']
#
#  activation_11 (Activation)     (None, 12, 12, 512)  0           ['conv2d_11[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 24, 24, 256)  524544     ['activation_11[0][0]']
#  spose)
#
#  tf.image.resize_1 (TFOpLambda)  (None, 24, 24, 256)  0          ['max_pooling2d_2[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 24, 24, 512)  0           ['conv2d_transpose_1[0][0]',
#                                                                   'tf.image.resize_1[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 22, 22, 256)  1179904     ['concatenate_1[0][0]']
#
#  activation_12 (Activation)     (None, 22, 22, 256)  0           ['conv2d_12[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 20, 20, 256)  590080      ['activation_12[0][0]']
#
#  activation_13 (Activation)     (None, 20, 20, 256)  0           ['conv2d_13[0][0]']
#
#  conv2d_transpose_2 (Conv2DTran  (None, 40, 40, 128)  131200     ['activation_13[0][0]']
#  spose)
#
#  tf.image.resize_2 (TFOpLambda)  (None, 40, 40, 128)  0          ['max_pooling2d_1[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 40, 40, 256)  0           ['conv2d_transpose_2[0][0]',
#                                                                   'tf.image.resize_2[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 38, 38, 128)  295040      ['concatenate_2[0][0]']
#
#  activation_14 (Activation)     (None, 38, 38, 128)  0           ['conv2d_14[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 36, 36, 128)  147584      ['activation_14[0][0]']
#
#  activation_15 (Activation)     (None, 36, 36, 128)  0           ['conv2d_15[0][0]']
#
#  conv2d_transpose_3 (Conv2DTran  (None, 72, 72, 64)  32832       ['activation_15[0][0]']
#  spose)
#
#  tf.image.resize_3 (TFOpLambda)  (None, 72, 72, 64)  0           ['max_pooling2d[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 72, 72, 128)  0           ['conv2d_transpose_3[0][0]',
#                                                                   'tf.image.resize_3[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 70, 70, 64)   73792       ['concatenate_3[0][0]']
#
#  activation_16 (Activation)     (None, 70, 70, 64)   0           ['conv2d_16[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 68, 68, 64)   36928       ['activation_16[0][0]']
#
#  activation_17 (Activation)     (None, 68, 68, 64)   0           ['conv2d_17[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 68, 68, 1)    65          ['activation_17[0][0]']
#
# ==================================================================================================
# Total params: 31,031,745
# Trainable params: 31,031,745
# Non-trainable params: 0
# __________________________________________________________________________________________________
