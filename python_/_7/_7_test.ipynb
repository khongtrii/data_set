# %%
def track_(x):
    x = str(x)
    assert x == "hello", "Hey, you must type 'hello'"

# %%
track_('h')
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 track_('h')
#
# Cell In[8], line 3, in track_(x)
#       1 def track_(x):
#       2     x = str(x)
# ----> 3     assert x == "hello", "Hey, you must type 'hello'"
#
# AssertionError: Hey, you must type 'hello'

# %%
df = pd.read_excel('itemBook.xlsx')

# %%
df.columns[:13]
# Out:
# Index(['TÊN MODEL', 'SERI', 'SỐ LƯỢNG', 'NGÀY NHẬP', 'NHÀ CUNG CẤP',
#        'GIÁ NHẬP', 'TRẠNG THÁI', 'NGÀY XUẤT', 'GIÁ XUẤT', 'BẢO HÀNH',
#        'THÔNG TIN KHÁCH HÀNG', 'NOTE', 'THÀNH CÔNG'],
#       dtype='object')

# %%
df = df.iloc[:, :13]

# %%
df.fillna('Empty')
# Out:
#                            TÊN MODEL      SERI  SỐ LƯỢNG  NGÀY NHẬP  \
# 0            ADAPTER( NGÀM LEICA M )     Empty         1 2022-07-08
# 1            ADAPTER( NGÀM LEICA M )     Empty         1 2022-07-08
# 2             Grip pin fujifilm XH1   8AQ00048         1 2022-06-25
# 3    LEN FUJI XC50-230 F4.5 / SLIVER  8DA00384         1 2022-04-27
# 4                LEN FUJI XF10-24 F4  85A10383         1 2022-07-18
# ..                               ...       ...       ...        ...
# 115                 FUJI XT20 SILVER  8CQ12297         1 2024-01-02
# 116               LEN FUJI XF56 F1.2  07A00188         1 2022-07-13
# 117      LENS CARLZEISS 50F2.8 MACRO  51093535         1 2023-10-11
# 118                       FUJI XS20B  3U302800         1 2023-11-24
# 119             LEN TAMRON 17-70F2.8    016159         1 2023-12-12
#
#                            NHÀ CUNG CẤP  GIÁ NHẬP TRẠNG THÁI  \
# 0                                    JP   2600000       USED
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   TÊN MODEL             120 non-null    object
#  1   SERI                  116 non-null    object
#  2   SỐ LƯỢNG              120 non-null    int64
#  3   NGÀY NHẬP             120 non-null    datetime64[ns]
#  4   NHÀ CUNG CẤP          120 non-null    object
#  5   GIÁ NHẬP              120 non-null    int64
#  6   TRẠNG THÁI            119 non-null    object
#  7   NGÀY XUẤT             4 non-null      datetime64[ns]
#  8   GIÁ XUẤT              119 non-null    float64
#  9   BẢO HÀNH              112 non-null    object
#  10  THÔNG TIN KHÁCH HÀNG  4 non-null      object
#  11  NOTE                  97 non-null     object
#  12  THÀNH CÔNG            22 non-null     object
# dtypes: datetime64[ns](2), float64(1), int64(2), object(8)
# memory usage: 12.3+ KB

# %%
import pandas as pd

# %%
help(pd.read_clipboard)
# Out:
# Help on function read_clipboard in module pandas.io.clipboards:
#
# read_clipboard(sep: 'str' = '\\s+', dtype_backend: 'DtypeBackend | lib.NoDefault' = <no_default>, **kwargs)
#     Read text from clipboard and pass to :func:`~pandas.read_csv`.
#
#     Parses clipboard contents similar to how CSV files are parsed
#     using :func:`~pandas.read_csv`.
#
#     Parameters
#     ----------
#     sep : str, default '\\s+'
#         A string or regex delimiter. The default of ``'\\s+'`` denotes
#         one or more whitespace characters.
#
#     dtype_backend : {'numpy_nullable', 'pyarrow'}, default 'numpy_nullable'
#         Back-end data type applied to the resultant :class:`DataFrame`
#         (still experimental). Behaviour is as follows:
#
#         * ``"numpy_nullable"``: returns nullable-dtype-backed :class:`DataFrame`
#           (default).
#         * ``"pyarrow"``: returns pyarrow-backed nullable :class:`ArrowDtype`
#           DataFrame.
#
#         .. versionadded:: 2.0
#
# ...
